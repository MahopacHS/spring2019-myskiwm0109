# %% [markdown]
# ## Now You Code 1: Simple Plotting
#
# In this first now you code, you will execute some simple plotting in matplotlib and plot.ly
#
# In most cases you will be writing 1-2 lines of code. you will spend the majority of time looking through the documentation here:
#
# - http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html
# - https://plot.ly/pandas/
#
# Also try interactive help: `help(eye_df.plot)` for pandas and `help(eye_df.iplot)`  for plot.ly

# %%
import pandas as pd
import plotly as py
import matplotlib as plt
import cufflinks as cf
# %matplotlib inline
# Out:
# No handlers could be found for logger "_plotly_utils.optional_imports"

# %%
# !pip install cufflinks
# !pip install plotly
# !pip install folium
# Out:
# Collecting cufflinks
#   Downloading https://files.pythonhosted.org/packages/dd/c9/c6f3675387438929af73e1199c45a623205898bafeab5ccd713efe3b43c2/cufflinks-0.15.tar.gz (81kB)
#     100% |████████████████████████████████| 81kB 3.6MB/s ta 0:00:011
# Requirement already satisfied: numpy>=1.9.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (1.16.3)
# Requirement already satisfied: pandas>=0.19.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (0.23.4)
# Requirement already satisfied: plotly>=3.0.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (3.8.1)
# Requirement already satisfied: six>=1.9.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (1.11.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading https://files.pythonhosted.org/packages/5d/8d/3b5db14788091fc095677b40daea2b040b3222d0108220a1853db2e49113/colorlover-0.3.0.tar.gz
# Requirement already satisfied: setuptools>=34.4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (41.0.1)
# Requirement already satisfied: ipython>=5.3.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (5.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from cufflinks) (7.4.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from pandas>=0.19.2->cufflinks) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from pandas>=0.19.2->cufflinks) (2018.7)
# Requirement already satisfied: decorator>=4.0.6 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly>=3.0.0->cufflinks) (4.3.0)
# Requirement already satisfied: nbformat>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly>=3.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly>=3.0.0->cufflinks) (2.20.1)
# Requirement already satisfied: retrying>=1.3.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly>=3.0.0->cufflinks) (1.3.3)
# Requirement already satisfied: pathlib2; python_version == "2.7" or python_version == "3.3" in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (2.3.2)
# Requirement already satisfied: backports.shutil-get-terminal-size; python_version == "2.7" in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (1.0.0)
# Requirement already satisfied: simplegeneric>0.8 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (0.8.1)
# Requirement already satisfied: pygments in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (2.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (4.6.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (1.0.15)
# Requirement already satisfied: pickleshare in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipython>=5.3.0->cufflinks) (4.3.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.10.0)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.4.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly>=3.0.0->cufflinks) (2.6.0)
# Requirement already satisfied: ipython-genutils in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly>=3.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly>=3.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly>=3.0.0->cufflinks) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly>=3.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly>=3.0.0->cufflinks) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly>=3.0.0->cufflinks) (2018.10.15)
# Requirement already satisfied: scandir in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from pathlib2; python_version == "2.7" or python_version == "3.3"->ipython>=5.3.0->cufflinks) (1.9.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks) (0.6.0)
# Requirement already satisfied: wcwidth in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->cufflinks) (0.1.7)
# Requirement already satisfied: enum34 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from traitlets>=4.2->ipython>=5.3.0->cufflinks) (1.1.6)
# Requirement already satisfied: jupyter_client in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.2.3)
# Requirement already satisfied: tornado>=4.0 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.5.3)
# Requirement already satisfied: notebook>=4.4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (5.7.2)
# Requirement already satisfied: functools32 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly>=3.0.0->cufflinks) (3.2.3.post2)
# Requirement already satisfied: pyzmq>=13 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (17.1.2)
# Requirement already satisfied: singledispatch in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from tornado>=4.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.4.0.3)
# Requirement already satisfied: backports-abc>=0.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from tornado>=4.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.5)
# Requirement already satisfied: terminado>=0.8.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.8.1)
# Requirement already satisfied: prometheus-client in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.4.2)
# Requirement already satisfied: jinja2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (2.10)
# Requirement already satisfied: Send2Trash in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: nbconvert in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (5.4.0)
# Requirement already satisfied: ipaddress; python_version == "2.7" in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.0.22)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.1.0)
# Requirement already satisfied: mistune>=0.8.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: bleach in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: testpath in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.4.2)
# Requirement already satisfied: defusedxml in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.5.0)
# Requirement already satisfied: html5lib!=0.9999,!=0.99999,<0.99999999,>=0.999 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks) (0.9999999)
# Building wheels for collected packages: cufflinks, colorlover
#   Running setup.py bdist_wheel for cufflinks ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/c7/7f/d3/7d3146a1551614bf0b8eb631ac724d044dd341679e763b594b
#   Running setup.py bdist_wheel for colorlover ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/01/91/17/44d69cf8471e5b46d4a9100f9f50f63241d7aa5fd844d4ca40
# Successfully built cufflinks colorlover
# Installing collected packages: colorlover, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.15
# You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: plotly in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (3.8.1)
# Requirement already satisfied: decorator>=4.0.6 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly) (1.11.0)
# Requirement already satisfied: nbformat>=4.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: pytz in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly) (2018.7)
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly) (2.20.1)
# Requirement already satisfied: retrying>=1.3.3 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: ipython-genutils in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->plotly) (2018.10.15)
# Requirement already satisfied: functools32 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly) (3.2.3.post2)
# Requirement already satisfied: enum34 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from traitlets>=4.1->nbformat>=4.2->plotly) (1.1.6)
# You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/43/77/0287320dc4fd86ae8847bab6c34b5ec370e836a79c7b0c16680a3d9fd770/folium-0.8.3-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 4.6MB/s ta 0:00:01
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/a1/37/675c85871b923bb35ea9a5b516a1841428bd753d7f885d5921060dfd3c41/branca-0.3.1-py2-none-any.whl
# Requirement already satisfied: requests in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from folium) (2.20.1)
# Requirement already satisfied: six in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from folium) (1.11.0)
# Requirement already satisfied: jinja2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from folium) (1.16.3)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->folium) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->folium) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from requests->folium) (2018.10.15)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda2_501/lib/python2.7/site-packages (from jinja2->folium) (1.1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.8.3
# You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# setup the credentials
# Sign up for a FREE plot.ly account and get your API credentials. https://plot.ly/settings/api

py.tools.set_credentials_file(username='mmyskiw0109', api_key='GsOUD56jRPd8JNyppqX3')

# %%
eye_data = [ {'Eye Color' : 'Blue', 'Count' : 190 }, {'Eye Color' : 'Brown', 'Count' : 245 },
            {'Eye Color' : 'Green', 'Count' : 64 }, {'Eye Color' : 'Hazel', 'Count' : 93 } ]
eye_df = pd.DataFrame(eye_data)
eye_df
# Out:
#    Count Eye Color
# 0    190      Blue
# 1    245     Brown
# 2     64     Green
# 3     93     Hazel

# %%
hair_df =  pd.DataFrame( {'Hair Color' :pd.Series( ['Black', 'Blond', 'Brown', 'Red'], name='Hair Color'), 
                           'Count' : pd.Series( [108, 125, 286, 73], name = 'Count')} )
hair_df
# Out:
#    Count Hair Color
# 0    108      Black
# 1    125      Blond
# 2    286      Brown
# 3     73        Red

# %%
# plot a vertical bar chart of hair colors using pandas / matplotlib
# Hair color names on the X axis, and chart title of "Counts of Hair Colors"
hair_df.plot.bar(x = 'Hair Color',y = 'Count')

# %%
# plot the EXACT same thing using plotly / cufflinks
hair_df.iplot(kind="bar", labels = 'Hair Color', values='Count')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mmyskiw0109/2.embed" height="525px" width="100%"></iframe>

# %%
# next, plot a pie chart of EYE COLORS using pandas / matplotlib
# make sure to set the labels on the pie to 'Blue', 'Brown' etc...
eye_df.plot.pie(y = 'Count')

# %%
# plot the same pie chart with plot.ly 
eye_df.iplot(kind = 'pie', labels = 'Eye Color', values = 'Count')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-6-4fe148214d0e> in <module>()
#       1 # plot the same pie chart with plot.ly
# ----> 2 eye_df.iplot(kind = 'pie', labels = 'Eye Color', values = 'Count')
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/cufflinks/plotlytools.pyc in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1215 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1216                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1217 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1218
#    1219
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/cufflinks/plotlytools.pyc in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1461         else:
#    1462 		return py.iplot(figure,validate=validate,sharing=sharing,
# -> 1463 						filename=filename)
#    1464
#    1465
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/chart_studio/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     157     if 'auto_open' not in plot_options:
#     158         plot_options['auto_open'] = False
# --> 159     url = plot(figure_or_data, **plot_options)
#     160
#     161     if isinstance(figure_or_data, dict):
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/chart_studio/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     227         if ('type' in entry) and (entry['type'] == 'scattergl'):
#     228             continue
# --> 229         for key, val in list(entry.items()):
#     230             try:
#     231                 if len(val) > 40000:
#
# AttributeError: 'Pie' object has no attribute 'items'

# %%
# In this last step you will plot a scatter plot with both pandas and plotly / cufflinks
#let's get the data:
cars = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/cars/weight-vs-mpg.csv')
cars.sample(5)
# Out:
#     Weight   MPG
# 14   3.620  18.6
# 36   2.600  21.5
# 22   1.975  34.1
# 18   3.955  16.5
# 0    4.360  16.9

# %%
# plot use pandas / matplotlib to plot a scatter of weight vs mpg for cars
cars.plot.scatter(x = 'Weight',y = 'MPG')

# %%
# Use cufflinks to plot a scatter here.
cars.iplot(kind = 'scattter', labels = 'Weight', values = 'MPG')
# Out:
# PlotlyEmptyDataErrorTraceback (most recent call last)
# <ipython-input-17-0acb5f0dfb8c> in <module>()
#       1 # Use cufflinks to plot a scatter here.
# ----> 2 cars.iplot(kind = 'scattter', labels = 'Weight', values = 'MPG')
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/cufflinks/plotlytools.pyc in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1215 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1216                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1217 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1218
#    1219
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/cufflinks/plotlytools.pyc in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1461         else:
#    1462 		return py.iplot(figure,validate=validate,sharing=sharing,
# -> 1463 						filename=filename)
#    1464
#    1465
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/chart_studio/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     157     if 'auto_open' not in plot_options:
#     158         plot_options['auto_open'] = False
# --> 159     url = plot(figure_or_data, **plot_options)
#     160
#     161     if isinstance(figure_or_data, dict):
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/chart_studio/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     223     """
#     224     import plotly.tools
# --> 225     figure = plotly.tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     226     for entry in figure['data']:
#     227         if ('type' in entry) and (entry['type'] == 'scattergl'):
#
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/plotly/tools.pyc in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1150         if not figure['data']:
#    1151             raise exceptions.PlotlyEmptyDataError(
# -> 1152                 "Empty data list found. Make sure that you populated the "
#    1153                 "list of data objects you're sending and try again.\n"
#    1154                 "Questions? Visit support.plot.ly"
#
# PlotlyEmptyDataError: Empty data list found. Make sure that you populated the list of data objects you're sending and try again.
# Questions? Visit support.plot.ly

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. What the problem attempted (analysis, code, and answered questions) ?
# 2. What the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
